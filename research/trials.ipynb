# %%
from box import ConfigBox

# %%
#downloading data from google drive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1pwposkImZL30vSmCRAhahakifbIRQXZW/view?usp=drive_link"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1pwposkImZL30vSmCRAhahakifbIRQXZW'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1pwposkImZL30vSmCRAhahakifbIRQXZW
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1pwposkImZL30vSmCRAhahakifbIRQXZW&confirm=t&uuid=367e38e2-eba4-44e1-93d3-88f8c5e82fdc
# To: d:\MBA Tech\ML_Project\Kidney-Disease-Classification-using-Deep-Learning\research\kidney-ct-scan-image.zip
# 100%|██████████| 57.7M/57.7M [00:29<00:00, 1.94MB/s]
# 'kidney-ct-scan-image.zip'
